# %%
import cv2
import torch
import time
import colorsys
import numpy as np
from deep_sort_realtime.deepsort_tracker import DeepSort
from ultralytics import YOLO
import supervision as sv
from tqdm import tqdm
from supervision.assets import VideoAssets
from collections import defaultdict, deque

# %%
FRAME_WIDTH=30
FRAME_HEIGHT=100
# SOURCE_POLYGONE = np.array([[18, 550], [1852, 608],[1335, 370], [534, 343]], dtype=np.float32)
SOURCE_POLYGONE = np.array([
    [50, 400],
    [900, 400],
    [900, 1400],
    [-900, 1400]
], dtype=np.float32)
BIRD_EYE_VIEW = np.array([[0, 0], [FRAME_WIDTH, 0], [FRAME_WIDTH, FRAME_HEIGHT],[0, FRAME_HEIGHT]], dtype=np.float32)
M = cv2.getPerspectiveTransform(SOURCE_POLYGONE, BIRD_EYE_VIEW)

SOURCE_VIDEO_PATH = "video/bacheha.mp4"
OUTPUT_VIDEO_PATH = "test/test_6.mp4"
BLUR_ID = None
CONF = 0.6
CLASS_ID = None

# %%
def read_frames(frame_skip_count = 1):
    i = 0
    while True:
        i += 1
        ret, frame = cap.read()
        if i % frame_skip_count == 0 :
            if not ret:
                break
            yield frame
        else:
            continue

def calculate_speed(distance, fps):
    return (distance *fps)

def calculate_distance(p1, p2):
    return np.sqrt((p2[0] - p1[0])**2 + (p2[1] - p1[1])**2)

# %%
def draw_corner_rect(img, bbox, line_length=30, line_thickness=5, rect_thickness=1,
                    rect_color=(255, 0, 255), line_color=(0, 255, 0)):
    x, y, w, h = bbox
    x1, y1 = x + w, y + h

    if rect_thickness != 0:
        cv2.rectangle(img, bbox, rect_color, rect_thickness)

    # Top Left  x, y
    cv2.line(img, (x, y), (x + line_length, y), line_color, line_thickness)
    cv2.line(img, (x, y), (x, y + line_length), line_color, line_thickness)

    # Top Right  x1, y
    cv2.line(img, (x1, y), (x1 - line_length, y), line_color, line_thickness)
    cv2.line(img, (x1, y), (x1, y + line_length), line_color, line_thickness)

    # Bottom Left  x, y1
    cv2.line(img, (x, y1), (x + line_length, y1), line_color, line_thickness)
    cv2.line(img, (x, y1), (x, y1 - line_length), line_color, line_thickness)

    # Bottom Right  x1, y1
    cv2.line(img, (x1, y1), (x1 - line_length, y1), line_color, line_thickness)
    cv2.line(img, (x1, y1), (x1, y1 - line_length), line_color, line_thickness)

    return img

# %%
# Initialize the video capture
cap = cv2.VideoCapture(SOURCE_VIDEO_PATH)
frame_generator = read_frames(2)
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

#Create mask to filter detections
pts = SOURCE_POLYGONE.astype(np.int32) 
pts = pts.reshape((-1, 1, 2))
polygon_mask = np.zeros((frame_height, frame_width), dtype=np.uint8)
cv2.fillPoly(polygon_mask, [pts], 255)

# Initialize the video writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
writer = cv2.VideoWriter(OUTPUT_VIDEO_PATH, fourcc, fps, (frame_width, frame_height))

# Initialize the DeepSort tracker
tracker = DeepSort(max_age=50)
# Load YOLO model
device = torch.device('cuda')
model = YOLO("models/yolov8n.pt").to(device)

classes_path = "configs/coco.names"
with open(classes_path, "r") as f:
    class_names = f.read().strip().split("\n")
np.random.seed(42)
colors = np.random.randint(0, 255, size=(len(class_names), 3))

# %%
frame_count = 0
start_time = time.time()
prev_positions={}
speed_accumulator={}

while True:
    try:
        frame = next(frame_generator)
    except StopIteration:
        break
    # Run model on each frame
    results = model(frame)
    detect = []
    for pred in results:
        for box in pred.boxes:    
            x1, y1, x2, y2 = map(int, box.xyxy[0] )
            confidence = box.conf[0]     
            label = box.cls[0]  
            
            # Filter out weak detections by confidence threshold and class_id
            if CLASS_ID is None:
                if confidence < CONF:
                    continue
            else:
                if class_id != CLASS_ID or confidence < CONF:
                    continue            
                
            if polygon_mask[(y1 + y2) // 2, (x1 + x2) // 2] == 255:
                detect.append([[x1, y1, x2 - x1, y2 - y1], confidence, int(label)])   
                
    tracks = tracker.update_tracks(detect, frame=frame)
    for track in tracks:
        if not track.is_confirmed():
            continue
        track_id = track.track_id    
        ltrb = track.to_ltrb()
        class_id = track.get_det_class()
        x1, y1, x2, y2 = map(int, ltrb)
        if polygon_mask[(y1+y2)//2,(x1+x2)//2] == 0:
            tracks.remove(track)
        color = colors[class_id]
        B, G, R = map(int, color)
        text = f"{track_id} - {class_names[class_id]}"
        center_pt = np.array([[(x1+x2)//2, (y1+y2)//2]], dtype=np.float32)
        transformed_pt = cv2.perspectiveTransform(center_pt[None, :, :], M)

        #Process distance and speed calculations by using previous predictions
        if track_id in prev_positions:
            prev_position = prev_positions[track_id]
            distance = calculate_distance(prev_position, transformed_pt[0][0])
            speed = calculate_speed(distance, fps)
            if track_id in speed_accumulator:
                speed_accumulator[track_id].append(speed)
                if len(speed_accumulator[track_id]) > 100:
                    speed_accumulator[track_id].pop(0)
            else:
                speed_accumulator[track_id] = []
                speed_accumulator[track_id].append(speed)
        prev_positions[track_id] = transformed_pt[0][0]

        # Draw bounding box and text
        frame = draw_corner_rect(frame, (x1, y1, x2 - x1, y2 - y1), line_length=15, line_thickness=3, rect_thickness=1, rect_color=(B, G, R), line_color=(R, G, B))
        #cv2.rectangle(frame, (x1, y1), (x2, y2), (B, G, R), 2)
        cv2.rectangle(frame, (x1 - 1, y1 - 20), (x1 + len(text) * 10, y1), (B, G, R), -1)
        cv2.putText(frame, text, (x1 + 5, y1 - 7), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
        cv2.polylines(frame, [pts], isClosed=True, color=(255, 0, 0), thickness=2)
        if track_id in speed_accumulator :
            avg_speed = sum(speed_accumulator[track_id]) / len(speed_accumulator[track_id])
            cv2.rectangle(frame, (x1 - 1, y1-40 ), (x1 + len(f"Speed: {avg_speed:.0f} km/h") * 10, y1-20), (0, 0, 255), -1)
            cv2.putText(frame, f"Speed: {avg_speed:.0f} km/h", (x1, y1 - 25), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 2)
        # Apply Gaussian Blur
        if BLUR_ID is not None and class_id == BLUR_ID:
            if 0 <= x1 < x2 <= frame.shape[1] and 0 <= y1 < y2 <= frame.shape[0]:
                frame[y1:y2, x1:x2] = cv2.GaussianBlur(frame[y1:y2, x1:x2], (99, 99), 3)
    # writer.write(frame)
    cv2.imshow('hehe', frame)
    frame_count += 1
    if frame_count % 10 == 0:
        elapsed_time = time.time() - start_time
        fps_calc = frame_count / elapsed_time
        print(f"FPS: {fps_calc:.2f}")

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
# Release video capture and writer
cap.release()
# writer.release()
# Out:
# 0: 640x384 6 cars, 1 truck, 8.4ms
# Speed: 1.6ms preprocess, 8.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 1 truck, 8.0ms
# Speed: 2.7ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 9.5ms
# Speed: 2.0ms preprocess, 9.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 8.2ms
# Speed: 2.6ms preprocess, 8.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 8.0ms
# Speed: 2.9ms preprocess, 8.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 1 truck, 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 1 traffic light, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 1 traffic light, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 8.9ms
# Speed: 2.1ms preprocess, 8.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 12.37
#
# 0: 640x384 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 2 trucks, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 2 trucks, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 1 truck, 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 1 cell phone, 8.1ms
# Speed: 2.0ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 1 toilet, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 14.46
#
# 0: 640x384 4 cars, 2 trucks, 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 1 traffic light, 8.9ms
# Speed: 2.5ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 3 trucks, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 3 trucks, 7.8ms
# Speed: 2.2ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 2 trucks, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 3 trucks, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 2 trucks, 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 4 trucks, 8.5ms
# Speed: 2.8ms preprocess, 8.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 3 trucks, 7.9ms
# Speed: 2.5ms preprocess, 7.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 15.37
#
# 0: 640x384 4 cars, 2 trucks, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 2 trucks, 1 traffic light, 8.5ms
# Speed: 2.6ms preprocess, 8.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 2 trucks, 9.2ms
# Speed: 2.5ms preprocess, 9.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 2 trucks, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 1 traffic light, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 bus, 1 traffic light, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 7.9ms
# Speed: 2.8ms preprocess, 7.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 15.16
#
# 0: 640x384 4 cars, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 1 truck, 7.7ms
# Speed: 2.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 traffic light, 7.6ms
# Speed: 2.2ms preprocess, 7.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 7.7ms
# Speed: 2.1ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 1 bus, 7.6ms
# Speed: 3.0ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 7.8ms
# Speed: 2.5ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 cars, 9.6ms
# Speed: 2.7ms preprocess, 9.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 1 traffic light, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 1 truck, 9.5ms
# Speed: 2.6ms preprocess, 9.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 14.86
#
# 0: 640x384 6 cars, 1 traffic light, 7.7ms
# Speed: 2.3ms preprocess, 7.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 traffic light, 7.6ms
# Speed: 2.0ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 1 truck, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 traffic light, 7.7ms
# Speed: 2.0ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 1 traffic light, 7.6ms
# Speed: 1.8ms preprocess, 7.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 traffic light, 7.6ms
# Speed: 2.1ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 1 boat, 1 traffic light, 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 2 trucks, 1 traffic light, 8.3ms
# Speed: 2.6ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 1 truck, 1 traffic light, 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 1 traffic light, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 14.76
#
# 0: 640x384 5 cars, 1 truck, 7.7ms
# Speed: 1.9ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 7.7ms
# Speed: 2.3ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cars, 1 truck, 1 toilet, 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 1 toilet, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 7.6ms
# Speed: 2.4ms preprocess, 7.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 9.2ms
# Speed: 1.9ms preprocess, 9.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 9.9ms
# Speed: 2.6ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cars, 1 truck, 9.3ms
# Speed: 2.8ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 14.50
#
# 0: 640x384 4 cars, 1 truck, 9.8ms
# Speed: 2.5ms preprocess, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 9.9ms
# Speed: 2.6ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 2 trucks, 9.3ms
# Speed: 2.5ms preprocess, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 2 trucks, 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 2 trucks, 7.9ms
# Speed: 2.3ms preprocess, 7.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 1 traffic light, 10.4ms
# Speed: 2.7ms preprocess, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cars, 2 trucks, 7.9ms
# Speed: 2.6ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 2 trucks, 8.7ms
# Speed: 3.1ms preprocess, 8.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 13.98
#
# 0: 640x384 5 cars, 1 truck, 9.7ms
# Speed: 2.6ms preprocess, 9.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 bus, 1 truck, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cars, 2 trucks, 1 toilet, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cars, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cars, 2 trucks, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cars, 2 trucks, 8.2ms
# Speed: 2.1ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cars, 2 motorcycles, 2 trucks, 1 traffic light, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cars, 1 truck, 1 traffic light, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 2 trucks, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cars, 1 motorcycle, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 14.60
#
# 0: 640x384 1 car, 1 motorcycle, 2 trucks, 8.7ms
# Speed: 2.5ms preprocess, 8.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 2 trucks, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 2 trucks, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cars, 2 trucks, 8.0ms
# Speed: 1.7ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 2 trucks, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cars, 2 trucks, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 2 trucks, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 2 trucks, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 2 trucks, 8.1ms
# Speed: 2.6ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 1 motorcycle, 2 trucks, 8.6ms
# Speed: 2.6ms preprocess, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 15.00
#
# 0: 640x384 1 car, 2 trucks, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cars, 2 trucks, 7.5ms
# Speed: 2.4ms preprocess, 7.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cars, 2 trucks, 8.8ms
# Speed: 2.9ms preprocess, 8.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cars, 2 trucks, 7.4ms
# Speed: 2.7ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cars, 2 trucks, 9.8ms
# Speed: 2.6ms preprocess, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 2 trucks, 10.2ms
# Speed: 2.7ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 2 trucks, 7.3ms
# Speed: 2.7ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 2 trucks, 9.9ms
# Speed: 2.6ms preprocess, 9.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 7.4ms
# Speed: 2.5ms preprocess, 7.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 14.64
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 7.4ms
# Speed: 2.4ms preprocess, 7.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 7.4ms
# Speed: 3.0ms preprocess, 7.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 2 trucks, 7.2ms
# Speed: 1.9ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 7.4ms
# Speed: 2.8ms preprocess, 7.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 7.3ms
# Speed: 2.0ms preprocess, 7.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 2 trucks, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 2 trucks, 1 toilet, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 2 trucks, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 14.69
#
# 0: 640x384 1 person, 1 car, 2 trucks, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 car, 2 trucks, 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 truck, 8.4ms
# Speed: 2.4ms preprocess, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 car, 1 truck, 6.9ms
# Speed: 2.5ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 car, 1 truck, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 car, 1 truck, 7.0ms
# Speed: 2.2ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 car, 1 truck, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 1 truck, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 car, 9.5ms
# Speed: 2.7ms preprocess, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 1 truck, 7.0ms
# Speed: 2.4ms preprocess, 7.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 14.64
#
# 0: 640x384 1 person, 2 cars, 9.0ms
# Speed: 2.0ms preprocess, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 car, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 car, 6.9ms
# Speed: 2.3ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 cars, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cars, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 car, 6.9ms
# Speed: 3.1ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 car, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 5 cars, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 15.20
#
# 0: 640x384 2 persons, 3 cars, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 cars, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 7.9ms
# Speed: 2.3ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 5 cars, 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 cars, 1 truck, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 cars, 1 truck, 7.0ms
# Speed: 2.1ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 15.79
#
# 0: 640x384 3 cars, 1 truck, 7.6ms
# Speed: 2.6ms preprocess, 7.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 1 truck, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 7.0ms
# Speed: 1.8ms preprocess, 7.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 cars, 7.0ms
# Speed: 2.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 16.26
#
# 0: 640x384 3 cars, 6.9ms
# Speed: 2.1ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 7.1ms
# Speed: 2.4ms preprocess, 7.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 8.1ms
# Speed: 1.8ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 8.1ms
# Speed: 2.8ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 8.1ms
# Speed: 2.2ms preprocess, 8.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 16.74
#
# 0: 640x384 4 cars, 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 8.4ms
# Speed: 2.2ms preprocess, 8.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 cars, 1 truck, 8.0ms
# Speed: 1.6ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.0ms
# Speed: 2.8ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 17.06
#
# 0: 640x384 1 person, 4 cars, 8.1ms
# Speed: 2.5ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.1ms
# Speed: 2.7ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.1ms
# Speed: 1.7ms preprocess, 8.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.5ms
# Speed: 2.3ms preprocess, 8.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 cars, 8.5ms
# Speed: 2.5ms preprocess, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 truck, 11.0ms
# Speed: 2.6ms preprocess, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.0ms
# Speed: 2.6ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 16.88
#
# 0: 640x384 1 person, 4 cars, 1 truck, 8.8ms
# Speed: 2.3ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 9.7ms
# Speed: 2.4ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 9.9ms
# Speed: 2.7ms preprocess, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.0ms
# Speed: 2.9ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 1 toilet, 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 16.58
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 8.1ms
# Speed: 3.0ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 8.0ms
# Speed: 2.0ms preprocess, 8.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 8.0ms
# Speed: 1.8ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 7.9ms
# Speed: 1.7ms preprocess, 7.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 16.74
#
# 0: 640x384 1 person, 3 cars, 7.4ms
# Speed: 1.8ms preprocess, 7.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 7.3ms
# Speed: 2.1ms preprocess, 7.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 5 cars, 7.4ms
# Speed: 2.1ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 7.2ms
# Speed: 2.2ms preprocess, 7.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 truck, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 9.7ms
# Speed: 2.6ms preprocess, 9.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 6.4ms
# Speed: 2.4ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 6.8ms
# Speed: 3.1ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 16.69
#
# 0: 640x384 1 person, 3 cars, 9.5ms
# Speed: 2.7ms preprocess, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 13.2ms
# Speed: 3.4ms preprocess, 13.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 truck, 9.9ms
# Speed: 2.9ms preprocess, 9.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 8.7ms
# Speed: 2.4ms preprocess, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 3 cars, 10.1ms
# Speed: 3.0ms preprocess, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 2 cars, 1 motorcycle, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 cars, 7.2ms
# Speed: 2.7ms preprocess, 7.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 8.0ms
# Speed: 2.7ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 4 cars, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 16.84
#
# 0: 640x384 2 persons, 5 cars, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 4 cars, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 5 cars, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 5 cars, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 bicycle, 4 cars, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 1 truck, 7.6ms
# Speed: 2.5ms preprocess, 7.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 cars, 6.5ms
# Speed: 1.9ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 17.16
#
# 0: 640x384 1 person, 5 cars, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 5 cars, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 5 cars, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 truck, 10.8ms
# Speed: 3.0ms preprocess, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 truck, 6.6ms
# Speed: 2.1ms preprocess, 6.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 5 cars, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 truck, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 5 cars, 1 truck, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 17.51
#
# 0: 640x384 1 person, 5 cars, 7.8ms
# Speed: 2.6ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 1 truck, 9.3ms
# Speed: 2.4ms preprocess, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 2 trucks, 9.0ms
# Speed: 2.6ms preprocess, 9.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 6.6ms
# Speed: 2.0ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 6 cars, 6.5ms
# Speed: 2.1ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 2 trucks, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 2 trucks, 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 5 cars, 1 truck, 8.2ms
# Speed: 1.9ms preprocess, 8.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 5 cars, 1 truck, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 17.81
#
# 0: 640x384 1 person, 4 cars, 1 truck, 8.1ms
# Speed: 1.9ms preprocess, 8.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 8.0ms
# Speed: 2.1ms preprocess, 8.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 5 cars, 2 trucks, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 6 cars, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 5 cars, 1 truck, 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 2 trucks, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 2 trucks, 8.9ms
# Speed: 2.2ms preprocess, 8.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 2 trucks, 8.0ms
# Speed: 2.6ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 2 trucks, 10.5ms
# Speed: 3.0ms preprocess, 10.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cars, 2 trucks, 8.1ms
# Speed: 2.4ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# FPS: 17.93
#
# 0: 640x384 1 person, 4 cars, 2 trucks, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 8.0ms
# Speed: 2.4ms preprocess, 8.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cars, 2 trucks, 11.3ms
# Speed: 3.0ms preprocess, 11.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 2 trucks, 9.4ms
# Speed: 3.1ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 2 trucks, 8.0ms
# Speed: 2.9ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 3 cars, 1 truck, 8.0ms
# Speed: 2.5ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 4 cars, 1 truck, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
